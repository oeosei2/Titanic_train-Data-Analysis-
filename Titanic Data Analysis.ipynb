# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # STATISTICAL DATA ANALYSIS OF TITANIC_TRAIN

# %%
data=pd.read_csv('titanic_train.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # EXPLORING THE DATA

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.shape
# Out:
# (891, 12)

# %% [markdown]
# # CLEANING OF DATA
# One can rename specific columns by running
# df.rename(columns={'old_name' : 'new_name'})

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print((data[:]==0).sum())  #columns with 0 entries
# Out:
# PassengerId      0
# Survived       549
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp          608
# Parch          678
# Ticket           0
# Fare            15
# Cabin            0
# Embarked         0
# dtype: int64

# %%
#percentages of 0 entries
print(((data[:]==0).sum())/891*100)
# Out:
# PassengerId     0.000000
# Survived       61.616162
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age             0.000000
# SibSp          68.237935
# Parch          76.094276
# Ticket          0.000000
# Fare            1.683502
# Cabin           0.000000
# Embarked        0.000000
# dtype: float64

# %% [markdown]
# #
# From the analysis made, almost 62% both male and famale were able to survived from the titanic_train

# %%
data.max()
# Out:
# PassengerId                            891
# Survived                                 1
# Pclass                                   3
# Name           van Melkebeke, Mr. Philemon
# Sex                                   male
# Age                                     80
# SibSp                                    8
# Parch                                    6
# Ticket                           WE/P 5735
# Fare                               512.329
# dtype: object

# %%
data.min()
# Out:
# PassengerId                      1
# Survived                         0
# Pclass                           1
# Name           Abbing, Mr. Anthony
# Sex                         female
# Age                           0.42
# SibSp                            0
# Parch                            0
# Ticket                      110152
# Fare                             0
# dtype: object

# %%
polos=data.loc[data['Survived'].idxmax()]
polos
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                           38
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
print('The oldest person who survived in Titanic_train is' ,polos['Name'] ,'with the age of' ,polos['Age'])
# Out:
# The oldest person who survived in Titanic_train is Cumings, Mrs. John Bradley (Florence Briggs Thayer) with the age of 38.0

# %%
sm=data.loc[data['Survived'].idxmin()]
sm
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
print('The smallest person who survived in Titanic_train is' ,sm['Name'] ,'with the age of' ,sm['Age'])
# Out:
# The smallest person who survived in Titanic_train is Braund, Mr. Owen Harris with the age of 22.0

# %% [markdown]
# # DATA VISUALIZATION

# %%
data['Survived'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of Survived Passengers')
plt.show()
print('0=Death', '1=Survived')
# Out:
# 0=Death 1=Survived

# %%
data['Survived'].value_counts().plot.bar(color=['r','g'])
plt.title('Distribution of Survived Passengers')
plt.xlabel('Survived')
plt.ylabel('Number of Passengers')
plt.show()
print('0=Death','1=Survived')
# Out:
# 0=Death 1=Survived

# %%
data['Sex'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of Sex by Passengers')
plt.show()

# %%
sns.heatmap(data.corr())
plt.show()
print('The heatmap show the relationship between the features')
# Out:
# The heatmap show the relationship between the features

# %%
data['Pclass'].value_counts().plot.bar(color=['violet','blue','brown'])
plt.title('Distribution Of Pclass by Passengers')
plt.xlabel('Pclass')
plt.ylabel('Number of Passengers')
plt.show()
print('1=1st class', '2=2nd class', '3=3rd class')
# Out:
# 1=1st class 2=2nd class 3=3rd class

# %%
bins=[0,15,30,45,60,75,90]
data['age']=pd.cut(data['Age'],bins)
sns.countplot(data['age'],hue=data['Survived'])
plt.title('Distribution of age by survived passengers')
plt.show()

# %%
sns.set_style('whitegrid')
sns.countplot(data['age'],hue=data['Sex'])
plt.show()

# %%
sns.set_style('whitegrid')
sns.violinplot(data['Survived'],data['Age']).set_title('Distribution of Age according to Passengers Survived')
plt.show()

# %%
plt.figure(figsize=(4,6))
sns.set_style('whitegrid')
sns.pairplot(data,hue='Survived')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
plt.boxplot(data['Survived'])
plt.show()

# %%
sns.set_style('whitegrid')
sns.countplot(data['Survived'],hue=data['Sex'])
plt.show()

# %% [markdown]
# # From the analysis above,
# **We have over 891 million of persons who were found in the titanic_train analysis. there were both male and female.From the analysis we have 64.8% of male and 35.2% of that of females.Hence, there were more of male persons than the females also about 541m plus with the percentage of 61.6% lost thier lives and about 350m plus of persons with the percentage of 38.4% Survived as compare to thier sex or gender over 90 plus of males Survived and 200 plus of females Survived etc..**

# %% [markdown]
# # SIMPLE DATA ANALYSIS BY

# %% [markdown]
# # OSEI OWUSU EUGENE
#                     Gmail: owusueugene237@gmail.com
#                     Tel: 0545263505

# %%
# %who
# Out:
# bins	 data	 np	 pd	 plt	 polos	 sm	 sns

# %%
# %history
# Out:
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# %matplotlib inline
# data=pd.read_csv('titanic_train.csv')
# data
# data.describe()
# data.dropna()
# data.corr()
# data.columns
# data.info()
# data.shape
# data.isnull().sum()
# print((data[:]==0).sum())  #columns with 0 entries
# #percentages of 0 entries
# print(((data[:]==0).sum())/891*100)
# data.max()
# data.min()
# polos=data.loc[data['Survived'].idxmax()]
# polos
# print('The oldest person who survived in Titanic_train is' ,polos['Name'] ,'with the age of' ,polos['Age'])
# sm=data.loc[data['Survived'].idxmin()]
# sm
# print('The smallest person who survived in Titanic_train is' ,sm['Name'] ,'with the age of' ,sm['Age'])
# data['Survived'].value_counts().plot.pie(autopct='%1.1f%%')
# plt.title('Distribution of Survived Passengers')
# plt.show()
# print('0=Death', '1=Survived')
# data['Survived'].value_counts().plot.bar(color=['r','g'])
# ...
